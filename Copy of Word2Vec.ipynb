# %% [markdown]
# # 1. Word2Vec Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
cd /content/drive/MyDrive/mos/Final_code
# Out:
# /content/drive/.shortcut-targets-by-id/14CExqOaVnlwyzMwJTA1hYv3DjasGJ09G/Final_code

# %%
import os
import gensim
#/content/drive/MyDrive/FrenchWE/Final_code/utils.py
from utils import *

import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

# %% [markdown]
# ## 1.1. Train Word2Vec Model

# %%
# !wget https://objectstore.e2enetworks.net/ai4b-public-nlu-nlg/v1-indiccorp/ta.txt
# Out:
# --2023-11-28 08:42:41--  https://objectstore.e2enetworks.net/ai4b-public-nlu-nlg/v1-indiccorp/ta.txt
# Resolving objectstore.e2enetworks.net (objectstore.e2enetworks.net)... 164.52.210.58, 101.53.152.33, 164.52.210.96, ...
# Connecting to objectstore.e2enetworks.net (objectstore.e2enetworks.net)|164.52.210.58|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11877039783 (11G) [text/plain]
# Saving to: ‘ta.txt’
#
# ta.txt               17%[==>                 ]   1.97G  17.3MB/s    eta 10m 8s ^C

# %% [markdown]
# ### Tamil

# %%
# I use a memory friendly iterator
text_w2t = MySentences(dirname='./Tamil/')

# %%
model_w2t = gensim.models.Word2Vec(sentences=text_w2t, vector_size=300, sg=0, hs=1)
if not os.path.exists('./WE_models'):
    os.mkdir('./WE_models')
model_w2t.save('WE_models/w2t_cbow_300D')
# Out:
# WARNING:gensim.models.word2vec:Both hierarchical softmax and negative sampling are activated. This is probably a mistake. You should set either 'hs=0' or 'negative=0' to disable one of them.

# %% [markdown]
# ### Punjabi

# %%
# I use a memory friendly iterator
text_w2p = MySentences(dirname='./Punjabi/')

# %%
model_w2p = gensim.models.Word2Vec(sentences=text_w2p, vector_size=300, sg=1, hs=1)
if not os.path.exists('./WE_models'):
    os.mkdir('./WE_models')
model_w2p.save('WE_models/w2p_sg_300D')
# Out:
# WARNING:gensim.models.word2vec:Both hierarchical softmax and negative sampling are activated. This is probably a mistake. You should set either 'hs=0' or 'negative=0' to disable one of them.

# %% [markdown]
# ## 1.2. Load Word2Vec Model

# %% [markdown]
# ### - Tamil Monolingual

# %%
model_w2v = gensim.models.Word2Vec.load('WE_models/w2t_cbow_300D')

# %% [markdown]
# - #### Similar Words

# %%
model_w2v.wv.most_similar('மனைவி')
# Out:
# [('கணவர்', 0.8260190486907959),
#  ('மகள்', 0.7676661014556885),
#  ('தாயார்', 0.7159507870674133),
#  ('மகன்', 0.7129124999046326),
#  ('மனைவி,', 0.7091261148452759),
#  ('தங்கை', 0.699622392654419),
#  ('மனைவிக்கு', 0.6880223155021667),
#  ('மனைவியான', 0.6870869994163513),
#  ('சகோதரி', 0.6707255244255066),
#  ('மனைவியை', 0.6441717743873596)]

# %% [markdown]
# ### - Punjabi Monolingual

# %%
model_w2v = gensim.models.Word2Vec.load('WE_models/w2p_cbow_300D')
model_w2v.wv.save_word2vec_format('w2t_cbow_300D.txt', binary=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-6dbccbfabca4> in <cell line: 1>()
# ----> 1 model_w2v = gensim.models.Word2Vec.load('WE_models/w2p_cbow_300D')
#       2 model_w2v.wv.save_word2vec_format('w2t_cbow_300D.txt', binary=False)
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/word2vec.py in load(cls, rethrow, *args, **kwargs)
#    1951         """
#    1952         try:
# -> 1953             model = super(Word2Vec, cls).load(*args, **kwargs)
#    1954             if not isinstance(model, Word2Vec):
#    1955                 rethrow = True
#
# /usr/local/lib/python3.10/dist-packages/gensim/utils.py in load(cls, fname, mmap)
#     484         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     485
# --> 486         obj = unpickle(fname)
#     487         obj._load_specials(fname, mmap, compress, subname)
#     488         obj.add_lifecycle_event("loaded", fname=fname)
#
# /usr/local/lib/python3.10/dist-packages/gensim/utils.py in unpickle(fname)
#    1458
#    1459     """
# -> 1460     with open(fname, 'rb') as f:
#    1461         return _pickle.load(f, encoding='latin1')  # needed because loading from S3 doesn't support readline()
#    1462
#
# /usr/local/lib/python3.10/dist-packages/smart_open/smart_open_lib.py in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, compression, transport_params)
#     175         transport_params = {}
#     176
# --> 177     fobj = _shortcut_open(
#     178         uri,
#     179         mode,
#
# /usr/local/lib/python3.10/dist-packages/smart_open/smart_open_lib.py in _shortcut_open(uri, mode, compression, buffering, encoding, errors, newline)
#     361         open_kwargs['errors'] = errors
#     362
# --> 363     return _builtin_open(local_path, mode, buffering=buffering, **open_kwargs)
#     364
#     365
#
# FileNotFoundError: [Errno 2] No such file or directory: 'WE_models/w2p_cbow_300D'

# %% [markdown]
# - #### Similar Words

# %%
model_w2v.wv.most_similar('')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-9607716edda3> in <cell line: 1>()
# ----> 1 model_w2v.wv.most_similar('')
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     839
#     840         # compute the weighted average of all keys
# --> 841         mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     842         all_keys = [
#     843             self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in get_mean_vector(self, keys, weights, pre_normalize, post_normalize, ignore_missing)
#     516                 total_weight += abs(weights[idx])
#     517             elif not ignore_missing:
# --> 518                 raise KeyError(f"Key '{key}' not present in vocabulary")
#     519
#     520         if total_weight > 0:
#
# KeyError: "Key '' not present in vocabulary"

# %% [markdown]
# ### Bilingual Model Training & Evaluation

# %%
# !python3 vecmap/map_embeddings.py --acl2017_seed /content/drive/MyDrive/FrenchWE/train_p2t.txt /content/drive/MyDrive/FrenchWE/w2v_cbow_300D.txt /content/drive/MyDrive/FrenchWE/w2t_cbow_300D.txt SRC_MAPPED.emb TRG_MAPPED.emb --cuda
# Out:
# python3: can't open file '/content/drive/.shortcut-targets-by-id/14CExqOaVnlwyzMwJTA1hYv3DjasGJ09G/Final_code/vecmap/map_embeddings.py': [Errno 2] No such file or directory

# %%
# !python3 vecmap/eval_translation.py SRC_MAPPED.emb TRG_MAPPED.emb -d /content/drive/MyDrive/FrenchWE/test_p2t.txt
# Out:
# python3: can't open file '/content/drive/.shortcut-targets-by-id/14CExqOaVnlwyzMwJTA1hYv3DjasGJ09G/Final_code/vecmap/eval_translation.py': [Errno 2] No such file or directory
